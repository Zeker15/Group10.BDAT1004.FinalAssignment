# %%
import requests
import time
from pymongo import MongoClient

# client = MongoClient("mongodb://robgoudis:Password123@Cluster0.81vbxyz.mongodb.net:27017/stocks_db?ssl=true&ssl_cert_reqs=CERT_NONE")
uri = "mongodb://robgoudis:Password123@ac-9wgptts-shard-00-00.81vbxyz.mongodb.net:27017,ac-9wgptts-shard-00-01.81vbxyz.mongodb.net:27017,ac-9wgptts-shard-00-02.81vbxyz.mongodb.net:27017/?ssl=true&replicaSet=atlas-z80eec-shard-0&authSource=admin&retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri)
db = client.get_database('stocks_db')
records = db.intraday

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key

while True:
    url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AAPL&interval=5min&apikey=BOYLBJ2VXTVDVBGS'
    r = requests.get(url)
    if r.status_code == 200:
        data = r.json()
        print(data)
        records.insert_one(data)
        time.sleep(60)
    else:
        exit()
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'AAPL', '3. Last Refreshed': '2023-04-19 20:00:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2023-04-19 20:00:00': {'1. open': '167.1700', '2. high': '167.2900', '3. low': '167.1500', '4. close': '167.2500', '5. volume': '9142'}, '2023-04-19 19:55:00': {'1. open': '167.1400', '2. high': '167.1900', '3. low': '167.1200', '4. close': '167.1900', '5. volume': '3656'}, '2023-04-19 19:50:00': {'1. open': '167.1800', '2. high': '167.2000', '3. low': '167.1100', '4. close': '167.1100', '5. volume': '3283'}, '2023-04-19 19:45:00': {'1. open': '167.2000', '2. high': '167.3000', '3. low': '167.0800', '4. close': '167.1100', '5. volume': '8558'}, '2023-04-19 19:40:00': {'1. open': '167.2300', '2. high': '167.3100', '3. low': '167.2100', '4. close': '167.3100', '5. volume': '1905'}, '2023-04-19 19:35:00': {'1. open': '167.3300
# ...

# %%
import requests
import time
from pymongo import MongoClient

#client = MongoClient("mongodb://robgoudis:Password123@Cluster0.81vbxyz.mongodb.net:27017/stocks_db?ssl=true&ssl_cert_reqs=CERT_NONE")

uri = "mongodb://robgoudis:Password123@ac-9wgptts-shard-00-00.81vbxyz.mongodb.net:27017,ac-9wgptts-shard-00-01.81vbxyz.mongodb.net:27017,ac-9wgptts-shard-00-02.81vbxyz.mongodb.net:27017/?ssl=true&replicaSet=atlas-z80eec-shard-0&authSource=admin&retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri)
db = client.get_database('stocks_db')
records = db.intraday

list(records.find({}))
# Out:
# [{'_id': ObjectId('643d99f2255e7eee9e20a960'),
#   'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#    '2. Symbol': 'AAPL',
#    '3. Last Refreshed': '2023-04-14 20:00:00',
#    '4. Interval': '5min',
#    '5. Output Size': 'Compact',
#    '6. Time Zone': 'US/Eastern'},
#   'Time Series (5min)': {'2023-04-14 20:00:00': {'1. open': '165.0000',
#     '2. high': '165.0000',
#     '3. low': '164.8500',
#     '4. close': '165.0000',
#     '5. volume': '4920'},
#    '2023-04-14 19:55:00': {'1. open': '165.1400',
#     '2. high': '165.1400',
#     '3. low': '165.0000',
#     '4. close': '165.0000',
#     '5. volume': '12573'},
#    '2023-04-14 19:50:00': {'1. open': '165.1500',
#     '2. high': '165.1600',
#     '3. low': '165.1500',
#     '4. close': '165.1600',
#     '5. volume': '1172'},
#    '2023-04-14 19:45:00': {'1. open': '165.1500',
#     '2. high': '165.1700',
#     '3. low': '165.1500',
#     '4. close': '165.1700',
# ...

# %%
import requests
import time
from pymongo.mongo_client import MongoClient

uri = "mongodb://robgoudis:Password123@ac-9wgptts-shard-00-00.81vbxyz.mongodb.net:27017,ac-9wgptts-shard-00-01.81vbxyz.mongodb.net:27017,ac-9wgptts-shard-00-02.81vbxyz.mongodb.net:27017/?ssl=true&replicaSet=atlas-z80eec-shard-0&authSource=admin&retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
